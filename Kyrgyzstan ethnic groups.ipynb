# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from matplotlib.pyplot import pie, axis, show

# %%
df = pd.read_csv('number.csv', thousands=',')

# %%
df
# Out:
#            Date    1926     1939     1959     1970     1979     1989     1999  \
# 0        Kyrgyz  661171   754323   836831  1284773  1687382  2229663  3128147
# 1        Uzbeks  110463   151551   218640   332638   426194   550096   664950
# 2      Russians  116436   302916   623562   855935   911703   916558   603201
# 3       Dungans    6004     5921    11088    19837    26661    36928    51766
# 4       Uyghurs    7540     9412    13757    24872    29817    36779    46944
# 5        Tajiks    2667    10670    15221    21927    23209    33518    42636
# 6         Turks      44       33      542     3076     5160    21294    33327
# 7       Kazakhs    1766    23925    20067    21998    27442    37318    42657
# 8        Tatars    4902    20017    56209    68827    71744    70068    45438
# 9        Azeris    3631     7724    10428    12536    17207    15775    14014
# 10      Koreans       9      508     3622     9404    14481    18355    19784
# ...

# %% [markdown]
# https://www.geeksforgeeks.org/update-column-value-of-csv-in-python/

# %%
# dropping the other value
df = df.drop(df[(df.Date == "Total")].index)
df
# Out:
#            Date    1926    1939    1959     1970     1979     1989     1999  \
# 0        Kyrgyz  661171  754323  836831  1284773  1687382  2229663  3128147
# 1        Uzbeks  110463  151551  218640   332638   426194   550096   664950
# 2      Russians  116436  302916  623562   855935   911703   916558   603201
# 3       Dungans    6004    5921   11088    19837    26661    36928    51766
# 4       Uyghurs    7540    9412   13757    24872    29817    36779    46944
# 5        Tajiks    2667   10670   15221    21927    23209    33518    42636
# 6         Turks      44      33     542     3076     5160    21294    33327
# 7       Kazakhs    1766   23925   20067    21998    27442    37318    42657
# 8        Tatars    4902   20017   56209    68827    71744    70068    45438
# 9        Azeris    3631    7724   10428    12536    17207    15775    14014
# 10      Koreans       9     508    3622     9404    14481    18355    19784
# ...

# %%
sums = df.groupby(df["Date"])["2021"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
sums = df.groupby(df["Date"])["2019"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
sums = df.groupby(df["Date"])["2009"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
sums = df.groupby(df["Date"])["1999"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
sums = df.groupby(df["Date"])["1989"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
sums = df.groupby(df["Date"])["1979"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
sums = df.groupby(df["Date"])["1970"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
sums = df.groupby(df["Date"])["1959"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
sums = df.groupby(df["Date"])["1939"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
sums = df.groupby(df["Date"])["1926"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()
